# %%
#import dependencies
import numpy as np
import pandas as pd
from pprint import pprint
import re
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# add gridlines to each of my .plt plots
import matplotlib.pyplot as plt
print(plt.style.available) #check what styles are available
plt.style.use('seaborn-v0_8-whitegrid')
# plt.style.use('seaborn-v0_8-notebook')
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
# Load CSV from a folder named 'Resources'
survey_df = pd.read_csv('../Resources/MentalHealthTechWorkplace2014.csv')
survey_df.head(15)

# # There's an option to download via pulling latest copy from Kaggle API. can explore later
# import kagglehub

# # Download latest version
# path = kagglehub.dataset_download("osmi/mental-health-in-tech-survey")

# print("Path to dataset files:", path)

## how to use Kaggle API: https://www.kaggle.com/docs/api#authentication
# Out:
#               Timestamp  Age  Gender         Country state self_employed  \
# 0   2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1   2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2   2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3   2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4   2014-08-27 11:30:22   31    Male   United States    TX           NaN
# 5   2014-08-27 11:31:22   33    Male   United States    TN           NaN
# 6   2014-08-27 11:31:50   35  Female   United States    MI           NaN
# 7   2014-08-27 11:32:05   39       M          Canada   NaN           NaN
# 8   2014-08-27 11:32:39   42  Female   United States    IL           NaN
# 9   2014-08-27 11:32:43   23    Male          Canada   NaN           NaN
# 10  2014-08-27 11:32:44   31    Male   United States    OH           NaN
# 11  2014-08-27 11:32:49   29    male        Bulgaria   NaN           NaN
# 12  2014-08-27 11:33:23   42  female   United States    CA           NaN
# 13  2014-08-27 11:33:26   36    Male   United States    CT           NaN
# 14  2014-08-27 11:33:57   27    Male          Canada   NaN           NaN
#
#    family_history treatment work_interfere    no_employees  ...  \
# 0              No       Yes          Often            6-25  ...
# 1              No        No         Rarely  More than 1000  ...
# 2              No        No         Rarely            6-25  ...
# 3             Yes       Yes          Often          26-100  ...
# 4              No        No          Never         100-500  ...
# 5             Yes        No      Sometimes            6-25  ...
# 6             Yes       Yes      Sometimes             1-5  ...
# 7              No        No          Never             1-5  ...
# 8             Yes       Yes      Sometimes         100-500  ...
# 9              No        No          Never          26-100  ...
# 10             No       Yes      Sometimes            6-25  ...
# 11             No        No          Never         100-500  ...
# 12            Yes       Yes      Sometimes          26-100  ...
# 13            Yes        No          Never        500-1000  ...
# 14             No        No          Never            6-25  ...
#
#                  leave mental_health_consequence phys_health_consequence  \
# 0        Somewhat easy                        No                      No
# 1           Don't know                     Maybe                      No
# 2   Somewhat difficult                        No                      No
# 3   Somewhat difficult                       Yes                     Yes
# 4           Don't know                        No                      No
# 5           Don't know                        No                      No
# 6   Somewhat difficult                     Maybe                   Maybe
# 7           Don't know                        No                      No
# 8       Very difficult                     Maybe                      No
# 9           Don't know                        No                      No
# 10          Don't know                        No                      No
# 11          Don't know                        No                      No
# 12  Somewhat difficult                       Yes                     Yes
# 13          Don't know                        No                      No
# 14       Somewhat easy                        No                      No
#
#        coworkers    supervisor mental_health_interview phys_health_interview  \
# 0   Some of them           Yes                      No                 Maybe
# 1             No            No                      No                    No
# 2            Yes           Yes                     Yes                   Yes
# 3   Some of them            No                   Maybe                 Maybe
# 4   Some of them           Yes                     Yes                   Yes
# 5            Yes           Yes                      No                 Maybe
# 6   Some of them            No                      No                    No
# 7             No            No                      No                    No
# 8            Yes           Yes                      No                 Maybe
# 9            Yes           Yes                   Maybe                 Maybe
# 10  Some of them           Yes                      No                    No
# 11           Yes           Yes                     Yes                   Yes
# 12           Yes           Yes                   Maybe                 Maybe
# 13           Yes           Yes                      No                    No
# 14  Some of them  Some of them                   Maybe                   Yes
#
#    mental_vs_physical obs_consequence  \
# 0                 Yes              No
# 1          Don't know              No
# 2                  No              No
# 3                  No             Yes
# 4          Don't know              No
# 5          Don't know              No
# 6          Don't know              No
# 7                  No              No
# 8                  No              No
# 9                 Yes              No
# 10         Don't know              No
# 11         Don't know              No
# 12                 No             Yes
# 13         Don't know              No
# 14                Yes              No
#
#                                              comments
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  I'm not on my company's health insurance which...
# 14                                                NaN
#
# [15 rows x 27 columns]

# %%
survey_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Timestamp                  1259 non-null   object
#  1   Age                        1259 non-null   int64
#  2   Gender                     1259 non-null   object
#  3   Country                    1259 non-null   object
#  4   state                      744 non-null    object
#  5   self_employed              1241 non-null   object
#  6   family_history             1259 non-null   object
#  7   treatment                  1259 non-null   object
#  8   work_interfere             995 non-null    object
#  9   no_employees               1259 non-null   object
#  10  remote_work                1259 non-null   object
#  11  tech_company               1259 non-null   object
#  12  benefits                   1259 non-null   object
#  13  care_options               1259 non-null   object
#  14  wellness_program           1259 non-null   object
#  15  seek_help                  1259 non-null   object
#  16  anonymity                  1259 non-null   object
#  17  leave                      1259 non-null   object
#  18  mental_health_consequence  1259 non-null   object
#  19  phys_health_consequence    1259 non-null   object
#  20  coworkers                  1259 non-null   object
#  21  supervisor                 1259 non-null   object
#  22  mental_health_interview    1259 non-null   object
#  23  phys_health_interview      1259 non-null   object
#  24  mental_vs_physical         1259 non-null   object
#  25  obs_consequence            1259 non-null   object
#  26  comments                   164 non-null    object
# dtypes: int64(1), object(26)
# memory usage: 265.7+ KB

# %%
survey_df.describe()
# Out:
#                 Age
# count  1.259000e+03
# mean   7.942815e+07
# std    2.818299e+09
# min   -1.726000e+03
# 25%    2.700000e+01
# 50%    3.100000e+01
# 75%    3.600000e+01
# max    1.000000e+11

# %% [markdown]
# ### Some notes to myself:
# - will need to update gender to Male, Famle, and Other if applicable. Some Males put M or lowercase male or female instead and it will be categorized as a different value. also have at least 1 "agender" and one that has "cis", "male-leaning", "trans", "androdgynous" (sp?), "not sure what that really means", and more
# - need to check how counties were input (dropdown ok but if manual entry, need to check for abbreviations and spelling errors)
# - same for state
# - figure out what to do for state NaNs... if I'll even use them as features, that is
# - can explore comments (maybe code them based on something - manually or LLM?)
# - I have time and data timestamps. may need to import timestamp (sub-)library. but it's marked as object datatype...
# - only got .describe() for age due to being only numerical... can I do something similar with time? or is it better to do viz to check the others?
# - need to check non-nulls of self-employed (Y/N or other format?)
# - all Y/N can be made encoded binary (**CHECK WHICH ARE y/n ONLY. SOME ARE 3 CHOICES WITH maybe**) and categories (Little/Lot/No/etc.) can be encoded with dummies?
# - scaled numerical (ex. age) can use standard scalar?
# - may group tech_company: all tech workers(CHECK IF THIS IS TRUE) but group by primarily a tech company vs not (**NEED TO SEE HOW FORMATTED**)
# - I'd like to have some consideration for the comments given (ex. not feel supported but all positive answers aside from comment, low understanding of MH support evidenced in comment, started in new job so not sure about response (more than 1 of these), etc.)
# - row 990 can be dropped: "8 year old" not responding helpfully. maybe check big outliers for age and any other relevant columns. need to figure out a system for gender (and comments?)
# - check to see how much left after fix gender values, do whatev with nulls, etc --> see if want to limit to just US.
# - 1259 rows... should be OK for ML (cluster or regression... prob regression if predicting TBH).

# %%
# preview the columns that were cut off in general .head() above
survey_df[["remote_work", "tech_company", "benefits", "care_options", "wellness_program", "seek_help", "anonymity"]].head()
# Out:
#   remote_work tech_company    benefits care_options wellness_program  \
# 0          No          Yes         Yes     Not sure               No
# 1          No           No  Don't know           No       Don't know
# 2          No          Yes          No           No               No
# 3          No          Yes          No          Yes               No
# 4         Yes          Yes         Yes           No       Don't know
#
#     seek_help   anonymity
# 0         Yes         Yes
# 1  Don't know  Don't know
# 2          No  Don't know
# 3          No          No
# 4  Don't know  Don't know

# %%
# how many nulls
pprint(survey_df.isnull().sum())
# Out:
# Timestamp                       0
# Age                             0
# Gender                          0
# Country                         0
# state                         515
# self_employed                  18
# family_history                  0
# treatment                       0
# work_interfere                264
# no_employees                    0
# remote_work                     0
# tech_company                    0
# benefits                        0
# care_options                    0
# wellness_program                0
# seek_help                       0
# anonymity                       0
# leave                           0
# mental_health_consequence       0
# phys_health_consequence         0
# coworkers                       0
# supervisor                      0
# mental_health_interview         0
# phys_health_interview           0
# mental_vs_physical              0
# obs_consequence                 0
# comments                     1095
# dtype: int64

# %%
# preview some of the nulls for all the columns
nulls_df = survey_df[survey_df.isnull().any(axis=1)]
nulls_df.tail()
# Out:
#                 Timestamp  Age Gender         Country state self_employed  \
# 1254  2015-09-12 11:17:21   26   male  United Kingdom   NaN            No
# 1255  2015-09-26 01:07:35   32   Male   United States    IL            No
# 1256  2015-11-07 12:36:58   34   male   United States    CA            No
# 1257  2015-11-30 21:25:06   46      f   United States    NC            No
# 1258  2016-02-01 23:04:31   25   Male   United States    IL            No
#
#      family_history treatment work_interfere    no_employees  ...  \
# 1254             No       Yes            NaN          26-100  ...
# 1255            Yes       Yes          Often          26-100  ...
# 1256            Yes       Yes      Sometimes  More than 1000  ...
# 1257             No        No            NaN         100-500  ...
# 1258            Yes       Yes      Sometimes          26-100  ...
#
#                    leave mental_health_consequence phys_health_consequence  \
# 1254       Somewhat easy                        No                      No
# 1255  Somewhat difficult                        No                      No
# 1256  Somewhat difficult                       Yes                     Yes
# 1257          Don't know                       Yes                      No
# 1258          Don't know                     Maybe                      No
#
#          coworkers    supervisor mental_health_interview  \
# 1254  Some of them  Some of them                      No
# 1255  Some of them           Yes                      No
# 1256            No            No                      No
# 1257            No            No                      No
# 1258  Some of them            No                      No
#
#      phys_health_interview mental_vs_physical obs_consequence comments
# 1254                    No         Don't know              No      NaN
# 1255                    No                Yes              No      NaN
# 1256                    No                 No              No      NaN
# 1257                    No                 No              No      NaN
# 1258                    No         Don't know              No      NaN
#
# [5 rows x 27 columns]

# %% [markdown]
# ### More Notes to Self:
# - seemingly all of the rows have at least 1 null value; sometimes comments, sometimes self-employed Q, work interfere, state
# - I don't see issue with NaNs in comments, so far.
# - **need to check what a null for self-employed even means/implies...same for work interfere and state**

# %%
# preview some of the non-null comments
non_null_comments = survey_df[survey_df['comments'].notnull()]
non_null_comments.head(20)
# Out:
#                Timestamp  Age                 Gender         Country state  \
# 13   2014-08-27 11:33:26   36                   Male   United States    CT
# 15   2014-08-27 11:34:00   29                 female   United States    IL
# 16   2014-08-27 11:34:20   23                   Male  United Kingdom   NaN
# 24   2014-08-27 11:36:48   33                   male   United States    CA
# 25   2014-08-27 11:37:08   35                   male   United States    TN
# 33   2014-08-27 11:39:36   42                   Male   United States    WA
# 45   2014-08-27 11:43:36   38                 Female   United States    TX
# 49   2014-08-27 11:44:43   30                   male   United States    IL
# 59   2014-08-27 11:47:56   33                   male          Canada   NaN
# 66   2014-08-27 11:51:34   23                 Female       Australia   NaN
# 93   2014-08-27 12:15:11   18  something kinda male?          Russia   NaN
# 100  2014-08-27 12:18:14   26                 female          Canada   NaN
# 106  2014-08-27 12:23:59   35                      M   United States    OR
# 141  2014-08-27 12:38:18   37                   Male  United Kingdom   NaN
# 144  2014-08-27 12:39:18   30                 Female   United States    PA
# 158  2014-08-27 12:43:28   27                   male   United States    UT
# 159  2014-08-27 12:43:40   25                   Male   United States    IL
# 160  2014-08-27 12:43:53   36                   Male  United Kingdom   NaN
# 164  2014-08-27 12:46:03   33                      F   United States    WA
# 165  2014-08-27 12:47:25   27                  Woman  United Kingdom   NaN
#
#     self_employed family_history treatment work_interfere    no_employees  \
# 13            NaN            Yes        No          Never        500-1000
# 15            NaN            Yes       Yes         Rarely          26-100
# 16            NaN             No       Yes      Sometimes          26-100
# 24             No            Yes       Yes         Rarely          26-100
# 25             No            Yes       Yes      Sometimes  More than 1000
# 33             No            Yes       Yes      Sometimes          26-100
# 45             No            Yes       Yes      Sometimes          26-100
# 49             No            Yes       Yes         Rarely          26-100
# 59             No            Yes       Yes          Often            6-25
# 66             No            Yes       Yes          Often             1-5
# 93             No             No        No            NaN          26-100
# 100            No            Yes       Yes      Sometimes          26-100
# 106            No            Yes       Yes      Sometimes          26-100
# 141           Yes             No       Yes      Sometimes  More than 1000
# 144            No            Yes        No            NaN  More than 1000
# 158            No             No       Yes         Rarely          26-100
# 159            No            Yes       Yes      Sometimes          26-100
# 160            No             No       Yes      Sometimes  More than 1000
# 164           Yes            Yes       Yes      Sometimes             1-5
# 165           Yes            Yes        No            NaN             1-5
#
#      ...               leave mental_health_consequence  \
# 13   ...          Don't know                        No
# 15   ...       Somewhat easy                        No
# 16   ...           Very easy                     Maybe
# 24   ...          Don't know                        No
# 25   ...           Very easy                       Yes
# 33   ...           Very easy                     Maybe
# 45   ...       Somewhat easy                        No
# 49   ...          Don't know                     Maybe
# 59   ...  Somewhat difficult                       Yes
# 66   ...           Very easy                        No
# 93   ...       Somewhat easy                        No
# 100  ...      Very difficult                       Yes
# 106  ...       Somewhat easy                        No
# 141  ...      Very difficult                       Yes
# 144  ...          Don't know                     Maybe
# 158  ...  Somewhat difficult                     Maybe
# 159  ...           Very easy                     Maybe
# 160  ...       Somewhat easy                     Maybe
# 164  ...      Very difficult                        No
# 165  ...       Somewhat easy                        No
#
#     phys_health_consequence     coworkers    supervisor  \
# 13                       No           Yes           Yes
# 15                       No           Yes  Some of them
# 16                       No  Some of them            No
# 24                       No           Yes           Yes
# 25                       No  Some of them           Yes
# 33                       No  Some of them  Some of them
# 45                       No  Some of them           Yes
# 49                       No  Some of them           Yes
# 59                       No            No            No
# 66                       No  Some of them           Yes
# 93                       No           Yes           Yes
# 100                      No            No            No
# 106                      No  Some of them           Yes
# 141                     Yes  Some of them            No
# 144                   Maybe  Some of them  Some of them
# 158                      No  Some of them           Yes
# 159                      No  Some of them            No
# 160                   Maybe  Some of them  Some of them
# 164                      No  Some of them           Yes
# 165                      No           Yes           Yes
#
#     mental_health_interview phys_health_interview mental_vs_physical  \
# 13                       No                    No         Don't know
# 15                    Maybe                 Maybe         Don't know
# 16                    Maybe                 Maybe                 No
# 24                       No                   Yes         Don't know
# 25                       No                   Yes                 No
# 33                    Maybe                   Yes         Don't know
# 45                       No                    No                Yes
# 49                       No                    No         Don't know
# 59                       No                 Maybe         Don't know
# 66                       No                 Maybe                Yes
# 93                      Yes                   Yes         Don't know
# 100                      No                 Maybe                 No
# 106                      No                 Maybe                 No
# 141                      No                 Maybe                Yes
# 144                      No                 Maybe         Don't know
# 158                      No                    No         Don't know
# 159                      No                    No         Don't know
# 160                      No                 Maybe         Don't know
# 164                      No                   Yes                Yes
# 165                      No                 Maybe                Yes
#
#     obs_consequence                                           comments
# 13               No  I'm not on my company's health insurance which...
# 15               No  I have chronic low-level neurological issues t...
# 16               No  My company does provide healthcare but not to ...
# 24               No                Relatively new job. Ask again later
# 25               No  Sometimes I think  about using drugs for my me...
# 33               No  I selected my current employer based on its po...
# 45               No  Our health plan has covered my psychotherapy a...
# 49               No  I just started a new job last week hence a lot...
# 59               No  In addition to my own mental health issues I'v...
# 66               No                    Thanks for doing this research.
# 93               No  In Russia we have mandatory medical insurance....
# 100             Yes  In my previous workplace which had mental heal...
# 106              No  I've seen negative consequences towards mental...
# 141              No  I'm not a permanent employee so do not get the...
# 144              No  I'd be more worried about coworkers and workpl...
# 158             Yes  Had a co-worker disappear from work for a few ...
# 159             Yes  Family history of depression.  Currently deali...
# 160             Yes  I feel that my employer and colleagues have cr...
# 164              No  Many of these questions become irrelevant once...
# 165              No  as a UK-based company we don't have any medica...
#
# [20 rows x 27 columns]

# %%
pprint(non_null_comments['comments'])
# Out:
# 13      I'm not on my company's health insurance which...
# 15      I have chronic low-level neurological issues t...
# 16      My company does provide healthcare but not to ...
# 24                    Relatively new job. Ask again later
# 25      Sometimes I think  about using drugs for my me...
#                               ...
# 1223    Although my employer does everything they can ...
# 1232    I work at a large university with a track reco...
# 1234    i'm in a country with social health care so my...
# 1245    In australia all organisations of a certain si...
# 1249                                    Bipolar disorder
# Name: comments, Length: 164, dtype: object

# %%
#explore instances where state is null, but country is not; could be that NaNs at 'state' are due to out-of-USA participants...
NullStates = survey_df[survey_df['state'].isnull()]
NullStates_country = NullStates[NullStates['Country'].notnull()]
NullStates_country.head(20)
# Out:
#               Timestamp  Age Gender         Country state self_employed  \
# 2   2014-08-27 11:29:44   32   Male          Canada   NaN           NaN
# 3   2014-08-27 11:29:46   31   Male  United Kingdom   NaN           NaN
# 7   2014-08-27 11:32:05   39      M          Canada   NaN           NaN
# 9   2014-08-27 11:32:43   23   Male          Canada   NaN           NaN
# 11  2014-08-27 11:32:49   29   male        Bulgaria   NaN           NaN
# 14  2014-08-27 11:33:57   27   Male          Canada   NaN           NaN
# 16  2014-08-27 11:34:20   23   Male  United Kingdom   NaN           NaN
# 19  2014-08-27 11:35:08   36   Male          France   NaN           Yes
# 29  2014-08-27 11:38:18   37   Male  United Kingdom   NaN            No
# 30  2014-08-27 11:39:03   32   Male  United Kingdom   NaN            No
# 32  2014-08-27 11:39:31   30   male  United Kingdom   NaN            No
# 36  2014-08-27 11:41:37   29   Male          Canada   NaN            No
# 37  2014-08-27 11:41:50   38   Male        Portugal   NaN            No
# 40  2014-08-27 11:42:25   24   Male  United Kingdom   NaN            No
# 42  2014-08-27 11:43:07   27   Male          Canada   NaN            No
# 43  2014-08-27 11:43:10   18   Male     Netherlands   NaN            No
# 46  2014-08-27 11:43:45   28   Male  United Kingdom   NaN            No
# 48  2014-08-27 11:43:56   26      m          Canada   NaN           Yes
# 52  2014-08-27 11:45:33   31      M   United States   NaN            No
# 54  2014-08-27 11:46:36   28      M     Switzerland   NaN            No
#
#    family_history treatment work_interfere no_employees  ...  \
# 2              No        No         Rarely         6-25  ...
# 3             Yes       Yes          Often       26-100  ...
# 7              No        No          Never          1-5  ...
# 9              No        No          Never       26-100  ...
# 11             No        No          Never      100-500  ...
# 14             No        No          Never         6-25  ...
# 16             No       Yes      Sometimes       26-100  ...
# 19            Yes        No            NaN         6-25  ...
# 29             No        No      Sometimes         6-25  ...
# 30             No        No          Never         6-25  ...
# 32            Yes       Yes      Sometimes     500-1000  ...
# 36             No        No         Rarely          1-5  ...
# 37             No        No            NaN      100-500  ...
# 40             No       Yes      Sometimes         6-25  ...
# 42            Yes       Yes      Sometimes          1-5  ...
# 43             No        No          Often         6-25  ...
# 46             No        No            NaN       26-100  ...
# 48             No        No      Sometimes          1-5  ...
# 52             No        No            NaN      100-500  ...
# 54             No        No            NaN      100-500  ...
#
#                  leave mental_health_consequence phys_health_consequence  \
# 2   Somewhat difficult                        No                      No
# 3   Somewhat difficult                       Yes                     Yes
# 7           Don't know                        No                      No
# 9           Don't know                        No                      No
# 11          Don't know                        No                      No
# 14       Somewhat easy                        No                      No
# 16           Very easy                     Maybe                      No
# 19       Somewhat easy                        No                      No
# 29      Very difficult                       Yes                   Maybe
# 30          Don't know                       Yes                     Yes
# 32       Somewhat easy                     Maybe                      No
# 36           Very easy                       Yes                   Maybe
# 37       Somewhat easy                     Maybe                      No
# 40          Don't know                     Maybe                   Maybe
# 42      Very difficult                     Maybe                      No
# 43  Somewhat difficult                       Yes                   Maybe
# 46          Don't know                        No                   Maybe
# 48          Don't know                        No                      No
# 52          Don't know                     Maybe                   Maybe
# 54          Don't know                        No                      No
#
#        coworkers    supervisor mental_health_interview phys_health_interview  \
# 2            Yes           Yes                     Yes                   Yes
# 3   Some of them            No                   Maybe                 Maybe
# 7             No            No                      No                    No
# 9            Yes           Yes                   Maybe                 Maybe
# 11           Yes           Yes                     Yes                   Yes
# 14  Some of them  Some of them                   Maybe                   Yes
# 16  Some of them            No                   Maybe                 Maybe
# 19  Some of them  Some of them                   Maybe                 Maybe
# 29  Some of them            No                      No                 Maybe
# 30  Some of them  Some of them                      No                 Maybe
# 32  Some of them           Yes                      No                   Yes
# 36  Some of them            No                      No                    No
# 37  Some of them  Some of them                      No                 Maybe
# 40  Some of them            No                      No                   Yes
# 42  Some of them            No                      No                    No
# 43            No  Some of them                      No                    No
# 46  Some of them           Yes                   Maybe                   Yes
# 48           Yes           Yes                      No                    No
# 52  Some of them  Some of them                   Maybe                 Maybe
# 54            No            No                      No                 Maybe
#
#    mental_vs_physical obs_consequence  \
# 2                  No              No
# 3                  No             Yes
# 7                  No              No
# 9                 Yes              No
# 11         Don't know              No
# 14                Yes              No
# 16                 No              No
# 19         Don't know              No
# 29                 No              No
# 30                 No              No
# 32         Don't know              No
# 36         Don't know              No
# 37                 No              No
# 40                 No             Yes
# 42                Yes              No
# 43                 No              No
# 46         Don't know              No
# 48                Yes              No
# 52         Don't know              No
# 54         Don't know              No
#
#                                              comments
# 2                                                 NaN
# 3                                                 NaN
# 7                                                 NaN
# 9                                                 NaN
# 11                                                NaN
# 14                                                NaN
# 16  My company does provide healthcare but not to ...
# 19                                                NaN
# 29                                                NaN
# 30                                                NaN
# 32                                                NaN
# 36                                                NaN
# 37                                                NaN
# 40                                                NaN
# 42                                                NaN
# 43                                                NaN
# 46                                                NaN
# 48                                                NaN
# 52                                                NaN
# 54                                                NaN
#
# [20 rows x 27 columns]

# %%
pprint(NullStates_country.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 515 entries, 2 to 1254
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Timestamp                  515 non-null    object
#  1   Age                        515 non-null    int64
#  2   Gender                     515 non-null    object
#  3   Country                    515 non-null    object
#  4   state                      0 non-null      object
#  5   self_employed              508 non-null    object
#  6   family_history             515 non-null    object
#  7   treatment                  515 non-null    object
#  8   work_interfere             393 non-null    object
#  9   no_employees               515 non-null    object
#  10  remote_work                515 non-null    object
#  11  tech_company               515 non-null    object
#  12  benefits                   515 non-null    object
#  13  care_options               515 non-null    object
#  14  wellness_program           515 non-null    object
#  15  seek_help                  515 non-null    object
#  16  anonymity                  515 non-null    object
#  17  leave                      515 non-null    object
#  18  mental_health_consequence  515 non-null    object
#  19  phys_health_consequence    515 non-null    object
#  20  coworkers                  515 non-null    object
#  21  supervisor                 515 non-null    object
#  22  mental_health_interview    515 non-null    object
#  23  phys_health_interview      515 non-null    object
#  24  mental_vs_physical         515 non-null    object
#  25  obs_consequence            515 non-null    object
#  26  comments                   60 non-null     object
# dtypes: int64(1), object(26)
# memory usage: 112.7+ KB
# None

# %%
print(f"The number of participants who had state as null but were also in the USA is: {NullStates_country[NullStates_country['Country'] == 'United States']['Country'].count()}")
NullStates_country[NullStates_country['Country'] == 'United States'].head()
# Out:
# The number of participants who had state as null but were also in the USA is: 11
#                Timestamp  Age  Gender        Country state self_employed  \
# 52   2014-08-27 11:45:33   31       M  United States   NaN            No
# 294  2014-08-27 14:15:57   56    Male  United States   NaN            No
# 367  2014-08-27 15:13:33   36    Male  United States   NaN            No
# 525  2014-08-27 17:32:04   41  Female  United States   NaN            No
# 574  2014-08-27 20:52:20   50    Male  United States   NaN            No
#
#     family_history treatment work_interfere    no_employees  ...       leave  \
# 52              No        No            NaN         100-500  ...  Don't know
# 294             No       Yes          Never  More than 1000  ...  Don't know
# 367            Yes       Yes          Often         100-500  ...   Very easy
# 525            Yes       Yes         Rarely        500-1000  ...   Very easy
# 574             No        No          Never          26-100  ...  Don't know
#
#     mental_health_consequence phys_health_consequence     coworkers  \
# 52                      Maybe                   Maybe  Some of them
# 294                        No                   Maybe           Yes
# 367                        No                      No  Some of them
# 525                     Maybe                   Maybe  Some of them
# 574                        No                      No            No
#
#        supervisor mental_health_interview phys_health_interview  \
# 52   Some of them                   Maybe                 Maybe
# 294  Some of them                      No                 Maybe
# 367  Some of them                      No                    No
# 525  Some of them                      No                    No
# 574            No                      No                 Maybe
#
#     mental_vs_physical obs_consequence comments
# 52          Don't know              No      NaN
# 294         Don't know              No      NaN
# 367         Don't know              No      NaN
# 525                Yes              No      NaN
# 574                 No              No      NaN
#
# [5 rows x 27 columns]

# %%
# non-USA countries that have null for state column

noUSA_df = survey_df[survey_df['Country'] != 'United States']
# noUSA_df.head()
noUSA_nullStates = noUSA_df[noUSA_df['state'].isnull()]
pprint(noUSA_nullStates.info())
noUSA_nullStates.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 504 entries, 2 to 1254
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Timestamp                  504 non-null    object
#  1   Age                        504 non-null    int64
#  2   Gender                     504 non-null    object
#  3   Country                    504 non-null    object
#  4   state                      0 non-null      object
#  5   self_employed              497 non-null    object
#  6   family_history             504 non-null    object
#  7   treatment                  504 non-null    object
#  8   work_interfere             385 non-null    object
#  9   no_employees               504 non-null    object
#  10  remote_work                504 non-null    object
#  11  tech_company               504 non-null    object
#  12  benefits                   504 non-null    object
#  13  care_options               504 non-null    object
#  14  wellness_program           504 non-null    object
#  15  seek_help                  504 non-null    object
#  16  anonymity                  504 non-null    object
#  17  leave                      504 non-null    object
#  18  mental_health_consequence  504 non-null    object
#  19  phys_health_consequence    504 non-null    object
#  20  coworkers                  504 non-null    object
#  21  supervisor                 504 non-null    object
#  22  mental_health_interview    504 non-null    object
#  23  phys_health_interview      504 non-null    object
#  24  mental_vs_physical         504 non-null    object
#  25  obs_consequence            504 non-null    object
#  26  comments                   58 non-null     object
# dtypes: int64(1), object(26)
# memory usage: 110.2+ KB
# None
#               Timestamp  Age Gender         Country state self_employed  \
# 2   2014-08-27 11:29:44   32   Male          Canada   NaN           NaN
# 3   2014-08-27 11:29:46   31   Male  United Kingdom   NaN           NaN
# 7   2014-08-27 11:32:05   39      M          Canada   NaN           NaN
# 9   2014-08-27 11:32:43   23   Male          Canada   NaN           NaN
# 11  2014-08-27 11:32:49   29   male        Bulgaria   NaN           NaN
#
#    family_history treatment work_interfere no_employees  ...  \
# 2              No        No         Rarely         6-25  ...
# 3             Yes       Yes          Often       26-100  ...
# 7              No        No          Never          1-5  ...
# 9              No        No          Never       26-100  ...
# 11             No        No          Never      100-500  ...
#
#                  leave mental_health_consequence phys_health_consequence  \
# 2   Somewhat difficult                        No                      No
# 3   Somewhat difficult                       Yes                     Yes
# 7           Don't know                        No                      No
# 9           Don't know                        No                      No
# 11          Don't know                        No                      No
#
#        coworkers supervisor mental_health_interview phys_health_interview  \
# 2            Yes        Yes                     Yes                   Yes
# 3   Some of them         No                   Maybe                 Maybe
# 7             No         No                      No                    No
# 9            Yes        Yes                   Maybe                 Maybe
# 11           Yes        Yes                     Yes                   Yes
#
#    mental_vs_physical obs_consequence comments
# 2                  No              No      NaN
# 3                  No             Yes      NaN
# 7                  No              No      NaN
# 9                 Yes              No      NaN
# 11         Don't know              No      NaN
#
# [5 rows x 27 columns]

# %%
# non-USA countries that have values in state column
noUSA_yesStates = noUSA_df[noUSA_df['state'].notnull()]
pprint(noUSA_yesStates.info())
noUSA_yesStates.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 319 to 1179
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Timestamp                  4 non-null      object
#  1   Age                        4 non-null      int64
#  2   Gender                     4 non-null      object
#  3   Country                    4 non-null      object
#  4   state                      4 non-null      object
#  5   self_employed              4 non-null      object
#  6   family_history             4 non-null      object
#  7   treatment                  4 non-null      object
#  8   work_interfere             3 non-null      object
#  9   no_employees               4 non-null      object
#  10  remote_work                4 non-null      object
#  11  tech_company               4 non-null      object
#  12  benefits                   4 non-null      object
#  13  care_options               4 non-null      object
#  14  wellness_program           4 non-null      object
#  15  seek_help                  4 non-null      object
#  16  anonymity                  4 non-null      object
#  17  leave                      4 non-null      object
#  18  mental_health_consequence  4 non-null      object
#  19  phys_health_consequence    4 non-null      object
#  20  coworkers                  4 non-null      object
#  21  supervisor                 4 non-null      object
#  22  mental_health_interview    4 non-null      object
#  23  phys_health_interview      4 non-null      object
#  24  mental_vs_physical         4 non-null      object
#  25  obs_consequence            4 non-null      object
#  26  comments                   2 non-null      object
# dtypes: int64(1), object(26)
# memory usage: 896.0+ bytes
# None
#                 Timestamp  Age              Gender       Country state  \
# 319   2014-08-27 14:28:28   29                male        Latvia    NY
# 488   2014-08-27 16:21:54   26                Male        Israel    MD
# 989   2014-08-29 09:10:58    8  A little about you  Bahamas, The    IL
# 1179  2014-09-26 10:05:55   25              female      Bulgaria    UT
#
#      self_employed family_history treatment work_interfere no_employees  ...  \
# 319             No             No        No            NaN       26-100  ...
# 488             No             No        No      Sometimes         6-25  ...
# 989            Yes            Yes       Yes          Often          1-5  ...
# 1179            No             No       Yes      Sometimes       26-100  ...
#
#               leave mental_health_consequence phys_health_consequence  \
# 319   Somewhat easy                     Maybe                   Maybe
# 488       Very easy                     Maybe                      No
# 989       Very easy                       Yes                     Yes
# 1179     Don't know                     Maybe                   Maybe
#
#          coworkers    supervisor mental_health_interview  \
# 319   Some of them  Some of them                      No
# 488   Some of them           Yes                      No
# 989            Yes           Yes                     Yes
# 1179           Yes  Some of them                   Maybe
#
#      phys_health_interview mental_vs_physical obs_consequence  \
# 319                     No         Don't know              No
# 488                  Maybe                Yes              No
# 989                    Yes                Yes             Yes
# 1179                    No                 No              No
#
#                                                comments
# 319                                                 NaN
# 488   Israel has public health insurance for everyon...
# 989
# 1179                                                NaN
#
# [4 rows x 27 columns]

# %%
# any countries are null?
nullCountries = survey_df[survey_df['Country'].isnull()]
nullCountries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Timestamp                  0 non-null      object
#  1   Age                        0 non-null      int64
#  2   Gender                     0 non-null      object
#  3   Country                    0 non-null      object
#  4   state                      0 non-null      object
#  5   self_employed              0 non-null      object
#  6   family_history             0 non-null      object
#  7   treatment                  0 non-null      object
#  8   work_interfere             0 non-null      object
#  9   no_employees               0 non-null      object
#  10  remote_work                0 non-null      object
#  11  tech_company               0 non-null      object
#  12  benefits                   0 non-null      object
#  13  care_options               0 non-null      object
#  14  wellness_program           0 non-null      object
#  15  seek_help                  0 non-null      object
#  16  anonymity                  0 non-null      object
#  17  leave                      0 non-null      object
#  18  mental_health_consequence  0 non-null      object
#  19  phys_health_consequence    0 non-null      object
#  20  coworkers                  0 non-null      object
#  21  supervisor                 0 non-null      object
#  22  mental_health_interview    0 non-null      object
#  23  phys_health_interview      0 non-null      object
#  24  mental_vs_physical         0 non-null      object
#  25  obs_consequence            0 non-null      object
#  26  comments                   0 non-null      object
# dtypes: int64(1), object(26)
# memory usage: 0.0+ bytes

# %% [markdown]
# ### decide what to do with nulls - Notes To Self
# - if using location (state, country) focus on country, as state has NaNs and we're not sure why (ex. user error, D.C.?, etc.); 4 non-USA partcipants also had US states for their state selection... which is odd. 1 participant reported they were 8 years old. **need to check age distrbution and drop big outliers that don't make sense like the 8 year old**
# - check all possible inputs (and their counts) for gender, bc it was typed. work on getting this into uniform M/F/Other bins

# %%
yesUSA_df = survey_df[survey_df['Country'] == 'United States']
yesUSA_df.info()
yesUSA_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 751 entries, 0 to 1258
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Timestamp                  751 non-null    object
#  1   Age                        751 non-null    int64
#  2   Gender                     751 non-null    object
#  3   Country                    751 non-null    object
#  4   state                      740 non-null    object
#  5   self_employed              740 non-null    object
#  6   family_history             751 non-null    object
#  7   treatment                  751 non-null    object
#  8   work_interfere             607 non-null    object
#  9   no_employees               751 non-null    object
#  10  remote_work                751 non-null    object
#  11  tech_company               751 non-null    object
#  12  benefits                   751 non-null    object
#  13  care_options               751 non-null    object
#  14  wellness_program           751 non-null    object
#  15  seek_help                  751 non-null    object
#  16  anonymity                  751 non-null    object
#  17  leave                      751 non-null    object
#  18  mental_health_consequence  751 non-null    object
#  19  phys_health_consequence    751 non-null    object
#  20  coworkers                  751 non-null    object
#  21  supervisor                 751 non-null    object
#  22  mental_health_interview    751 non-null    object
#  23  phys_health_interview      751 non-null    object
#  24  mental_vs_physical         751 non-null    object
#  25  obs_consequence            751 non-null    object
#  26  comments                   104 non-null    object
# dtypes: int64(1), object(26)
# memory usage: 164.3+ KB
#              Timestamp  Age  Gender        Country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female  United States    IL           NaN
# 1  2014-08-27 11:29:37   44       M  United States    IN           NaN
# 4  2014-08-27 11:30:22   31    Male  United States    TX           NaN
# 5  2014-08-27 11:31:22   33    Male  United States    TN           NaN
# 6  2014-08-27 11:31:50   35  Female  United States    MI           NaN
#
#   family_history treatment work_interfere    no_employees  ...  \
# 0             No       Yes          Often            6-25  ...
# 1             No        No         Rarely  More than 1000  ...
# 4             No        No          Never         100-500  ...
# 5            Yes        No      Sometimes            6-25  ...
# 6            Yes       Yes      Sometimes             1-5  ...
#
#                 leave mental_health_consequence phys_health_consequence  \
# 0       Somewhat easy                        No                      No
# 1          Don't know                     Maybe                      No
# 4          Don't know                        No                      No
# 5          Don't know                        No                      No
# 6  Somewhat difficult                     Maybe                   Maybe
#
#       coworkers supervisor mental_health_interview phys_health_interview  \
# 0  Some of them        Yes                      No                 Maybe
# 1            No         No                      No                    No
# 4  Some of them        Yes                     Yes                   Yes
# 5           Yes        Yes                      No                 Maybe
# 6  Some of them         No                      No                    No
#
#   mental_vs_physical obs_consequence comments
# 0                Yes              No      NaN
# 1         Don't know              No      NaN
# 4         Don't know              No      NaN
# 5         Don't know              No      NaN
# 6         Don't know              No      NaN
#
# [5 rows x 27 columns]

# %%
noUSA_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 508 entries, 2 to 1254
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Timestamp                  508 non-null    object
#  1   Age                        508 non-null    int64
#  2   Gender                     508 non-null    object
#  3   Country                    508 non-null    object
#  4   state                      4 non-null      object
#  5   self_employed              501 non-null    object
#  6   family_history             508 non-null    object
#  7   treatment                  508 non-null    object
#  8   work_interfere             388 non-null    object
#  9   no_employees               508 non-null    object
#  10  remote_work                508 non-null    object
#  11  tech_company               508 non-null    object
#  12  benefits                   508 non-null    object
#  13  care_options               508 non-null    object
#  14  wellness_program           508 non-null    object
#  15  seek_help                  508 non-null    object
#  16  anonymity                  508 non-null    object
#  17  leave                      508 non-null    object
#  18  mental_health_consequence  508 non-null    object
#  19  phys_health_consequence    508 non-null    object
#  20  coworkers                  508 non-null    object
#  21  supervisor                 508 non-null    object
#  22  mental_health_interview    508 non-null    object
#  23  phys_health_interview      508 non-null    object
#  24  mental_vs_physical         508 non-null    object
#  25  obs_consequence            508 non-null    object
#  26  comments                   60 non-null     object
# dtypes: int64(1), object(26)
# memory usage: 111.1+ KB

# %%
# quick viz for countries
# Count occurrences of each country
country_counts = survey_df['Country'].value_counts()
# pprint(country_counts)

# Optionally limit to top N countries to avoid a cluttered pie chart
top_n = 10
country_counts_top = country_counts[:top_n]
pprint(country_counts_top)
other_count = country_counts[top_n:].sum()
pprint(f"Count of non-top countries: {other_count}")
if other_count > 0:
    country_counts_top['Other'] = other_count

# # Plot the pie chart
# plt.figure(figsize=(6, 6))
# plt.pie(
#     country_counts_top,
#     labels=country_counts_top.index,
#     autopct='%1.1f%%',
#     startangle=140,
#     textprops={'fontsize': 10}
# )
# plt.title('Country Distribution of Survey Respondents')
# plt.tight_layout()
# plt.show()

# Prepare data
labels = country_counts_top.index
sizes = country_counts_top.values

# # Define explode values to separate small slices slightly
# explode = [0.05 if pct < 5 else 0 for pct in (sizes / sizes.sum()) * 100]

# custom colors
colors = ['lightgreen', 'skyblue', 'gold', 'salmon', 'mediumpurple', 'red', 'pink', 'violet', 'lightyellow', 'orange', 'green']

# Plot pie chart
fig, ax = plt.subplots(figsize=(10, 10))
wedges, texts, autotexts = ax.pie(
    sizes,
    labels=labels,
    autopct='%1.1f%%',
    startangle=70,
    pctdistance=0.85,
    colors=colors,
    explode=None,
    textprops=dict(color="black", fontsize=10)
)
# Out:
# Country
# United States     751
# United Kingdom    185
# Canada             72
# Germany            45
# Ireland            27
# Netherlands        27
# Australia          21
# France             13
# India              10
# New Zealand         8
# Name: count, dtype: int64
# 'Count of non-top countries: 100'

# %%
# Other section is huge. might see better with bar chart
plt.figure(figsize=(12, 8))
country_counts.plot(kind='bar', color=colors[:len(country_counts_top)])

plt.title('Number of Survey Respondents by Country')
plt.xlabel('Country')
plt.ylabel('Count')
plt.xticks(rotation=90)  # Rotate x-axis labels for readability
plt.tight_layout()
plt.show()

# %%
# bar chart USA vs Other (all other countries binned)
# Create USA vs Other counts
usa_count = country_counts.get('United States', 0)
other_count = country_counts.sum() - usa_count

# Prepare data
counts_USAOther = pd.Series({'United States': usa_count, 'Other': other_count})

# Plot
plt.figure(figsize=(6, 6))
# counts.plot(kind='bar', color=['skyblue', 'gray'])
counts_USAOther.plot(kind='bar', color=colors[:len(counts_USAOther)])

plt.title('Survey Respondents: USA vs Other Countries')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# quick viz on whether gave comment by country
# Create a binary column: "Yes" if comment exists, "No" if NaN
survey_df['gave_comment'] = survey_df['comments'].notnull().map({True: 'Yes', False: 'No'})

# Group by country and comment presence
comment_by_country = survey_df.groupby(['Country', 'gave_comment']).size().unstack(fill_value=0)
comment_by_country = comment_by_country.sort_values(by='No', ascending=False)

# Keep top countries only
top_countries = survey_df['Country'].value_counts().head(10).index
comment_by_country = comment_by_country.loc[comment_by_country.index.isin(top_countries)]

# Plot
comment_by_country.plot(kind='bar', stacked=True, figsize=(10, 6), color=colors[:len(comment_by_country)])

plt.title('Comments Given by Country (Top 10)')
plt.xlabel('Country')
plt.ylabel('Number of Respondents')
plt.legend(['No Comment', 'Gave Comment'])
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# percent of commenters per country
comment_percent = comment_by_country.div(comment_by_country.sum(axis=1), axis=0) * 100

# comment_percent.plot(kind='bar', stacked=True, figsize=(10, 6), color=colors[:len(comment_by_country)])
# plt.title('Percentage of Comments Given by Country (Top 10)')
# plt.xlabel('Country')
# plt.ylabel('Percentage')
# plt.legend(['No Comment', 'Gave Comment'], loc='center left', bbox_to_anchor=(1.0, 0.5))
# plt.xticks(rotation=45)
# plt.tight_layout()
# plt.show()

comment_percent['Yes'].sort_values().plot(kind='barh', color='skyblue', figsize=(8, 6))
plt.xlabel('Percentage of Respondents Who Left a Comment')
plt.title('Comment Participation by Country (Top 10)')
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
#  gave comment by state (US Only)
comment_by_USAstate = survey_df.groupby(['state', 'gave_comment']).size().unstack(fill_value=0)
comment_by_USAstate = comment_by_USAstate.sort_values(by='Yes', ascending=False)

# Keep top states only
top_states = survey_df['state'].value_counts().head(10).index
comment_by_USAstate = comment_by_USAstate.loc[comment_by_USAstate.index.isin(top_states)]

# Plot
comment_by_USAstate.plot(kind='bar', stacked=True, figsize=(10, 6), color=colors[:len(comment_by_USAstate)])

plt.title('Comments Given by USA State (Top 10)')
plt.xlabel('state')
plt.ylabel('Number of Respondents')
plt.legend(['No Comment', 'Gave Comment'])
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# quick viz self employed by country
selfEmployed_by_country = survey_df.groupby(['Country', 'self_employed']).size().unstack(fill_value=0)
selfEmployed_by_country = selfEmployed_by_country.sort_values(by='Yes', ascending=False)
selfEmployed_by_country.head(10)

selfEmployed_by_country = selfEmployed_by_country.loc[selfEmployed_by_country.index.isin(top_countries)] 
#NOTE TO SELF: here, top_states is by number respondents from the state, not necessarily the highest number of self-employed responses so far

# Plot
selfEmployed_by_country.plot(kind='bar', stacked=True, figsize=(10, 6), color=colors[:len(selfEmployed_by_country)])

plt.title('Self-Employed by Countries (Top 10)')
plt.xlabel('Country')
plt.ylabel('Number of Respondents')
plt.legend(['Not Self-Employed', 'Self-Employed'])
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# slef-employed by state
selfEmployed_by_USAstate = survey_df.groupby(['state', 'self_employed']).size().unstack(fill_value=0)
selfEmployed_by_USAstate = selfEmployed_by_USAstate.sort_values(by='Yes', ascending=False)
selfEmployed_by_USAstate.head(10)

selfEmployed_by_USAstate = selfEmployed_by_USAstate.loc[selfEmployed_by_USAstate.index.isin(top_states)] 
#NOTE TO SELF: here, top_states is by number respondents from the state, not necessarily the highest number of self-employed responses so far

# Plot
selfEmployed_by_USAstate.plot(kind='bar', stacked=True, figsize=(10, 6), color=colors[:len(selfEmployed_by_USAstate)])

plt.title('Self-Employed by USA State (Top 10)')
plt.xlabel('state')
plt.ylabel('Number of Respondents')
plt.legend(['Not Self-Employed', 'Self-Employed'])
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Notes To Self
# - self-employed seems to be only small chunk of respondents on global and USA-state levels. Can keep for now, but maybe potentially drop.
# - Leaning toward using countries as a feature (instead of states) but need to check what counts look like once drop NaNs or weird outliers (ex. USA states but non-US country, 8 year old respondent)

# %%
sns.boxplot(x='Age', data=survey_df)
plt.title('Age Distribution with Outliers')
plt.show()

# %%
# check ages for weird input
pprint(survey_df['Age'].sort_values().head(10))
print("-------------------------")
pprint(survey_df['Age'].sort_values().tail(10))
print("-------------------------")
print(f"Current 'shape'/size (no changes): {survey_df.shape[0]}")
# Out:
# 715    -1726
# 143      -29
# 1127      -1
# 734        5
# 989        8
# 1090      11
# 282       18
# 287       18
# 43        18
# 482       18
# Name: Age, dtype: int64
# -------------------------
# 466              57
# 471              58
# 1236             60
# 297              60
# 952              61
# 520              62
# 560              65
# 1182             72
# 364             329
# 390     99999999999
# Name: Age, dtype: int64
# -------------------------
# Current 'shape'/size (no changes): 1259

# %% [markdown]
# ### Notes To Self
# - Boxplot shows some weird range in ages (to the power of 1e11!!!)
# - Ages have errors: (at low age range) -1726, -29, -1, 5, 8, 11 AND (at high age range) 99999999999, 329.

# %%
# Drop weird ages Option 1: Remove rows where age is less than 18, higher than 100
survey_df_clean = survey_df[(survey_df['Age'] >= 18) & (survey_df['Age'] <= 100)]
# survey_df_clean['Age'].sort_values().tail(10)
# survey_df_clean['Age'].sort_values().head(10)

# Check how many rows remain
print(f"Rows after removing outliers: {survey_df_clean.shape[0]}")
# Out:
# Rows after removing outliers: 1251

# %%
## Drop weird ages Option 2: Use IQR to detect and remove outliers - I worry about using this due to potential mean being skewed so horribly!
# Q1 = survey_df['Age'].quantile(0.25)
# Q3 = survey_df['Age'].quantile(0.75)
# IQR = Q3 - Q1

# # Define lower and upper bounds (e.g., ages below 18 or above 100)
# lower_bound = Q1 - 1.5 * IQR
# upper_bound = Q3 + 1.5 * IQR

# # Remove outliers
# survey_df_clean = survey_df[(survey_df['Age'] >= lower_bound) & (survey_df['age'] <= upper_bound)]

# # Check how many rows remain
# print(f"Rows after removing outliers: {survey_df_clean.shape[0]}")

# %%
# viz age distribution post age cleaning
sns.boxplot(x='Age', data=survey_df_clean)
plt.title('Age Distribution with Outliers')
plt.show()

survey_df_clean['Age'].value_counts().sort_index().plot(kind='hist', figsize=(8, 4), color='lightgreen', edgecolor = 'black')
plt.title('Participant Ages')
plt.xlabel('Age')
plt.ylabel('Number of Responses')
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
# viz for year (or month-year) participants responded
# make Timestamp into datetime (for line chart but also helpful later for any heatmaps)
survey_df_clean['Timestamp'] = pd.to_datetime(survey_df_clean['Timestamp']\
                                                     , errors='coerce'
                                                    )
pprint(survey_df_clean.dtypes)
print("--------------------")
print(f"Total nulls in Timestamp column: {survey_df_clean['Timestamp'].isnull().sum()}") #if no nulls, shouldn't be issue with dt convert

# NOTE: when do .loc ver of this, for whatever reason doesn't convert to dt
# Out:
# Timestamp                    datetime64[ns]
# Age                                   int64
# Gender                               object
# Country                              object
# state                                object
# self_employed                        object
# family_history                       object
# treatment                            object
# work_interfere                       object
# no_employees                         object
# remote_work                          object
# tech_company                         object
# benefits                             object
# care_options                         object
# wellness_program                     object
# seek_help                            object
# anonymity                            object
# leave                                object
# mental_health_consequence            object
# phys_health_consequence              object
# coworkers                            object
# supervisor                           object
# mental_health_interview              object
# phys_health_interview                object
# mental_vs_physical                   object
# obs_consequence                      object
# comments                             object
# gave_comment                         object
# dtype: object
# --------------------
# Total nulls in Timestamp column: 0
# C:\Users\musam\AppData\Local\Temp\ipykernel_12556\2475752288.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey_df_clean['Timestamp'] = pd.to_datetime(survey_df_clean['Timestamp']\

# %%
# add columns for years and month-years
survey_df_clean.loc[:, 'Year'] = survey_df_clean['Timestamp'].dt.year
survey_df_clean.loc[:, 'Month-Year'] = survey_df_clean['Timestamp'].dt.to_period('M')

survey_df_clean.head()
# Out:
# C:\Users\musam\AppData\Local\Temp\ipykernel_12556\1856284875.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey_df_clean.loc[:, 'Year'] = survey_df_clean['Timestamp'].dt.year
# C:\Users\musam\AppData\Local\Temp\ipykernel_12556\1856284875.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey_df_clean.loc[:, 'Month-Year'] = survey_df_clean['Timestamp'].dt.to_period('M')
#             Timestamp  Age  Gender         Country state self_employed  \
# 0 2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1 2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2 2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3 2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4 2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees  ...     coworkers  \
# 0             No       Yes          Often            6-25  ...  Some of them
# 1             No        No         Rarely  More than 1000  ...            No
# 2             No        No         Rarely            6-25  ...           Yes
# 3            Yes       Yes          Often          26-100  ...  Some of them
# 4             No        No          Never         100-500  ...  Some of them
#
#   supervisor mental_health_interview phys_health_interview mental_vs_physical  \
# 0        Yes                      No                 Maybe                Yes
# 1         No                      No                    No         Don't know
# 2        Yes                     Yes                   Yes                 No
# 3         No                   Maybe                 Maybe                 No
# 4        Yes                     Yes                   Yes         Don't know
#
#   obs_consequence comments gave_comment  Year Month-Year
# 0              No      NaN           No  2014    2014-08
# 1              No      NaN           No  2014    2014-08
# 2              No      NaN           No  2014    2014-08
# 3             Yes      NaN           No  2014    2014-08
# 4              No      NaN           No  2014    2014-08
#
# [5 rows x 30 columns]

# %%
# year distrib viz
# Count the number of responses per year
survey_df_clean['Year'].value_counts().sort_index().plot(kind='line', figsize=(8, 4), color='lightblue')

plt.title('Survey Responses by Year')
plt.xlabel('Year')
plt.ylabel('Number of Responses')
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
# month-year distrib viz
# Count the number of responses per month-year
survey_df_clean['Month-Year'].value_counts().sort_index().plot(kind='line', figsize=(8, 4), color='lightgreen')

plt.title('Survey Responses by Month-Year')
plt.xlabel('Month-Year')
plt.ylabel('Number of Responses')
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
# drop all participants outside of US that input a US state
# shape before changes
print(f"Shape before dropping non-US state errors: {survey_df_clean.shape}")

# Compound condition for dropping rows
condition = (survey_df_clean['Country'] != 'United States') & survey_df_clean['state'].notnull()

# Drop rows where the condition is true
survey_df_clean.drop(survey_df_clean[condition].index, inplace=True)

print(f"Shape after dropping non-US state errors: {survey_df_clean.shape}")
print("----------------------")
survey_df_clean.head()
# Out:
# Shape before dropping non-US state errors: (1251, 30)
# Shape after dropping non-US state errors: (1248, 30)
# ----------------------
# C:\Users\musam\AppData\Local\Temp\ipykernel_12556\1140776176.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey_df_clean.drop(survey_df_clean[condition].index, inplace=True)
#             Timestamp  Age  Gender         Country state self_employed  \
# 0 2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1 2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2 2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3 2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4 2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees  ...     coworkers  \
# 0             No       Yes          Often            6-25  ...  Some of them
# 1             No        No         Rarely  More than 1000  ...            No
# 2             No        No         Rarely            6-25  ...           Yes
# 3            Yes       Yes          Often          26-100  ...  Some of them
# 4             No        No          Never         100-500  ...  Some of them
#
#   supervisor mental_health_interview phys_health_interview mental_vs_physical  \
# 0        Yes                      No                 Maybe                Yes
# 1         No                      No                    No         Don't know
# 2        Yes                     Yes                   Yes                 No
# 3         No                   Maybe                 Maybe                 No
# 4        Yes                     Yes                   Yes         Don't know
#
#   obs_consequence comments gave_comment  Year Month-Year
# 0              No      NaN           No  2014    2014-08
# 1              No      NaN           No  2014    2014-08
# 2              No      NaN           No  2014    2014-08
# 3             Yes      NaN           No  2014    2014-08
# 4              No      NaN           No  2014    2014-08
#
# [5 rows x 30 columns]

# %%
# bin Gender column from many different strings to Man/Woman/Other

# find all unique text input for Gender
unique_genders = survey_df_clean['Gender'].unique()
# pprint(unique_genders)
# Sort the unique values alphabetically to help me later
sorted_unique_genders = sorted(unique_genders)
print(sorted_unique_genders)
# Out:
# ['Agender', 'Androgyne', 'Cis Female', 'Cis Male', 'Cis Man', 'Enby', 'F', 'Femake', 'Female', 'Female ', 'Female (cis)', 'Female (trans)', 'Genderqueer', 'Guy (-ish) ^_^', 'M', 'Mail', 'Make', 'Mal', 'Male', 'Male ', 'Male (CIS)', 'Male-ish', 'Malr', 'Man', 'Nah', 'Neuter', 'Trans woman', 'Trans-female', 'Woman', 'cis male', 'cis-female/femme', 'f', 'femail', 'female', 'fluid', 'm', 'maile', 'male', 'male leaning androgynous', 'msle', 'non-binary', 'ostensibly male, unsure what that really means', 'queer', 'queer/she/they', 'something kinda male?', 'woman']

# %%
# 1. define mapping with dict
gender_mapping = {
    'Cis Male': 'Man', 'Cis Man': 'Man', 'Guy (-ish) ^_^': 'Man', 'M': 'Man', 'Mail': 'Man', 'Make': 'Man', 'Mal': 'Man', 'Male': 'Man',\
    'Male ': 'Man', 'Male (CIS)': 'Man', 'Male-ish': 'Man', 'Malr': 'Man', 'Man': 'Man', 'cis male': 'Man', 'm': 'Man', 'maile': 'Man',\
    'male': 'Man', 'msle': 'Man', 'ostensibly male': 'Man', 'something kinda male?': 'Man',\
    
    'Cis Female': 'Woman', 'Femake': 'Woman', 'Female':'Woman', 'Female ':'Woman', 'Female (cis)':'Woman', 'Female (trans)':'Woman', \
    'Trans woman':'Woman', 'Trans-female':'Woman', 'Woman':'Woman', 'cis-female/femme': 'Woman', 'f': 'Woman', 'femail':'Woman', 
    'female':'Woman', 'woman': 'Woman', \
    
    'Agender': 'Other', 'Androgyne':'Other', 'Enby': 'Other', 'Genderqueer': 'Other', 'Nah': 'Other', 'Neuter': 'Other', \
    'gender non-conforming': 'Other', 'transgender': 'Other', 'fluid': 'Other', 'male leaning androgynous': 'Other', 'non-binary': 'Other',\
    'unsure what that really means': 'Other', 'queer': 'Other', 'queer/she/they': 'Other'
}

# 2. map onto df and bin to Other if not in dict
def map_gender(gender):
    for category, values in gender_mapping.items():
        # Check if gender matches any synonym in the list
        if gender in category:
            return values
    ## If no match found, return 'Other'
    else: return 'Other'

# 3. Apply the function to the Gender column
survey_df_clean['Gender_bin'] = survey_df_clean['Gender'].apply(map_gender)

#4. Check the updated Gender column
print(survey_df_clean['Gender_bin'].value_counts())
survey_df_clean.info()
survey_df_clean.head()
# Out:
# Gender_bin
# Man      986
# Woman    250
# Other     12
# Name: count, dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# Index: 1248 entries, 0 to 1258
# Data columns (total 31 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Timestamp                  1248 non-null   datetime64[ns]
#  1   Age                        1248 non-null   int64
#  2   Gender                     1248 non-null   object
#  3   Country                    1248 non-null   object
#  4   state                      735 non-null    object
#  5   self_employed              1230 non-null   object
#  6   family_history             1248 non-null   object
#  7   treatment                  1248 non-null   object
#  8   work_interfere             987 non-null    object
#  9   no_employees               1248 non-null   object
#  10  remote_work                1248 non-null   object
#  11  tech_company               1248 non-null   object
#  12  benefits                   1248 non-null   object
#  13  care_options               1248 non-null   object
#  14  wellness_program           1248 non-null   object
#  15  seek_help                  1248 non-null   object
#  16  anonymity                  1248 non-null   object
#  17  leave                      1248 non-null   object
#  18  mental_health_consequence  1248 non-null   object
#  19  phys_health_consequence    1248 non-null   object
#  20  coworkers                  1248 non-null   object
#  21  supervisor                 1248 non-null   object
#  22  mental_health_interview    1248 non-null   object
#  23  phys_health_interview      1248 non-null   object
#  24  mental_vs_physical         1248 non-null   object
#  25  obs_consequence            1248 non-null   object
#  26  comments                   160 non-null    object
#  27  gave_comment               1248 non-null   object
#  28  Year                       1248 non-null   int32
#  29  Month-Year                 1248 non-null   period[M]
#  30  Gender_bin                 1248 non-null   object
# dtypes: datetime64[ns](1), int32(1), int64(1), object(27), period[M](1)
# memory usage: 307.1+ KB
# C:\Users\musam\AppData\Local\Temp\ipykernel_12556\669761411.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey_df_clean['Gender_bin'] = survey_df_clean['Gender'].apply(map_gender)
#             Timestamp  Age  Gender         Country state self_employed  \
# 0 2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1 2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2 2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3 2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4 2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees  ... supervisor  \
# 0             No       Yes          Often            6-25  ...        Yes
# 1             No        No         Rarely  More than 1000  ...         No
# 2             No        No         Rarely            6-25  ...        Yes
# 3            Yes       Yes          Often          26-100  ...         No
# 4             No        No          Never         100-500  ...        Yes
#
#   mental_health_interview phys_health_interview mental_vs_physical  \
# 0                      No                 Maybe                Yes
# 1                      No                    No         Don't know
# 2                     Yes                   Yes                 No
# 3                   Maybe                 Maybe                 No
# 4                     Yes                   Yes         Don't know
#
#   obs_consequence comments gave_comment  Year Month-Year Gender_bin
# 0              No      NaN           No  2014    2014-08      Woman
# 1              No      NaN           No  2014    2014-08        Man
# 2              No      NaN           No  2014    2014-08        Man
# 3             Yes      NaN           No  2014    2014-08        Man
# 4              No      NaN           No  2014    2014-08        Man
#
# [5 rows x 31 columns]

# %% [markdown]
# For curiosities' sake, I could theoretically **automate this mapping process** a little, but not efficient in this situation for me. ChatGPT reccomendation for such a process:
# <br>
# <br> Steps:
# 1. **Categorize based on keywords:** You can define some common keywords for each category ("Man", "Woman", "Other") and try to match those keywords against the unique gender values.
# 2. **Use Regular Expressions:** This can help in matching multiple variations of keywords like "male", "female", "nonbinary", etc.
# 3. **Assign categories based on matches:** Group the values under each category automatically, and create a dictionary mapping the different variations to the categories.
# <br>
# ``` python
# import pandas as pd
# import re
#
# # Sample data (use your actual survey_df_clean in place of this)
# # Assuming 'Gender' column contains various gender input values.
# unique_genders = survey_df_clean['Gender'].unique()
#
# # Define keywords for categories
# man_keywords = ['man', 'male', 'M', 'm', 'masculine', 'boy', 'he']
# woman_keywords = ['woman', 'female', 'f', 'female', 'feminine', 'girl', 'she', 'lady']
# other_keywords = ['nonbinary', 'genderqueer', 'agender', 'other', 'transgender', 'dont know', 'unknown', 'gender non-conforming']
#
# # Initialize the mapping dictionary
# gender_mapping = {}
#
# # Function to categorize based on keyword match
# def categorize_gender(gender):
#     # Convert to lowercase to make it case insensitive
#     gender_lower = gender.lower()
#
#     # Check if any keyword matches the gender string (using regex for flexibility)
#     if any(re.search(r'\b' + re.escape(keyword) + r'\b', gender_lower) for keyword in man_keywords):
#         return 'Man'
#     elif any(re.search(r'\b' + re.escape(keyword) + r'\b', gender_lower) for keyword in woman_keywords):
#         return 'Woman'
#     elif any(re.search(r'\b' + re.escape(keyword) + r'\b', gender_lower) for keyword in other_keywords):
#         return 'Other'
#     else:
#         return 'Other'  # Default to 'Other' if no match is found
#
# # Create the mapping dictionary by categorizing each unique gender value
# for gender in unique_genders:
#     gender_mapping[gender] = categorize_gender(gender)
#
# # Print the mapping dictionary
# pprint(gender_mapping)
# ```

# %%
#  bin ages (reduce noise)

# %% [markdown]
# ### Need to Clean So Far:
# - **[DONE]** drop participants with odd ages
# - **[DONE]** drop participants with non-USA countries that have USA states input
# - **[DONE]** bin gender: Man/Woman/Other (counting trans women/men as declared identity)
# - **[DONE]** figure out whether to drop or bin years responded (ex. recession or something); most from 1 month in 2014, so I'll leave years as is for now and **not inlcude in features**
# - bin ages or keep continuous? if continuous, won't it be too many features later for ML? --> {see histogram} will bin in approx 20-year bins. Most respondents were less than 20 years old.
# - making nulls for self-employed to No? decided to **not bin** this.
# -
# - ]
#
# ##### Prep for Features for ML
# - encode yes/no (binary) and yes/no/maybe/etc. (scaled? dummies?)
# - bin ages to decrease issue of too many features...
# - do PCA to see what features may be more predictive/important
# - (depending on PCA)
#     1. drop comments (and comments_given) (can do future NLP on comments and use as feature?)
#     2.
# - [
#
#
# ##### Keep in mind for 2nd ML if time
# - alt target feature(s): work_interfere (for predict individual) OR obs_consequence (for workplace culture. ex. are features like not knowing benefits, not mentioning in interviews, etc. indicative/predictive of an environment where it is more/less likely to obs a conseq for MH struggles?)
# - []

# %%
# gender distrib viz
survey_df_clean['Gender_bin'].value_counts().plot(
    kind='pie',
    colormap='Set3',
    autopct='%1.1f%%',  # Add percentage labels
    startangle=90,      # Rotate start of pie chart
    figsize=(6, 6)      # Optional: control figure size
)

plt.title('Participants by Gender')
plt.ylabel('')  # Removes default 'Gender_bin' label
plt.xlabel('')  # Not needed for pie chart
plt.show()

# %%
# Group by gender and treatment
treatment_by_gender = survey_df_clean.groupby(['Gender_bin', 'treatment']).size().unstack().fillna(0)

# Normalize to get percentage
treatment_by_gender_percent = treatment_by_gender.div(treatment_by_gender.sum(axis=1), axis=0)

# Plot count
# treatment_by_gender_percent.plot(kind='bar', stacked=True, colormap='Pastel1', edgecolor='black')
treatment_by_gender.plot(kind='bar', stacked=True, colormap='Pastel1', edgecolor='black')
plt.title('Treatment vs No Treatment by Gender')
# plt.ylabel('Proportion')
plt.ylabel('Count')
plt.xlabel('Gender')
plt.xticks(rotation=45)
plt.legend(title='Treatment', loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

# plot percentage
treatment_by_gender_percent.plot(kind='bar', stacked=True, colormap='Pastel1', edgecolor='black')
plt.title('Treatment vs No Treatment by Gender')
plt.ylabel('Proportion')
plt.xlabel('Gender')
plt.xticks(rotation=45)
plt.legend(title='Treatment', loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

# %%
# tx by Company size
treatment_by_compsize = survey_df_clean.groupby(['no_employees', 'treatment']).size().unstack().fillna(0)

# Normalize to get percentage
treatment_by_compsize_percent = treatment_by_compsize.div(treatment_by_compsize.sum(axis=1), axis=0)

# Plot count
treatment_by_compsize.plot(kind='bar', stacked=True, colormap='Set3', edgecolor='black')
plt.title('Treatment vs No Treatment by Company Size')
plt.ylabel('Count')
plt.xlabel('Company Size (Number Employees)')
plt.xticks(rotation=45)
plt.legend(title='Treatment', loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

# Plot percentage
treatment_by_compsize_percent.plot(kind='bar', stacked=True, colormap='Set3', edgecolor='black')
plt.title('Treatment vs No Treatment by Company Size')
plt.ylabel('Proportion')
plt.xlabel('Company Size (Number Employees)')
plt.xticks(rotation=45)
plt.legend(title='Treatment', loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

# %%
#tx by remote
treatment_by_remote = survey_df_clean.groupby(['remote_work', 'treatment']).size().unstack().fillna(0)

# Normalize to get percentage
treatment_by_remote_percent = treatment_by_remote.div(treatment_by_remote.sum(axis=1), axis=0)


# Plot count
treatment_by_remote.plot(kind='bar', stacked=True, colormap='Pastel2', edgecolor='black')
plt.title('Treatment Seeking by Remote Role')
plt.ylabel('Count')
plt.xlabel('Remote Position (at least 50% of the time)')
plt.xticks(rotation=45)
plt.legend(title='Treatment', loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

# Plot proportion
treatment_by_remote_percent.plot(kind='bar', stacked=True, colormap='Pastel2', edgecolor='black')
plt.title('Treatment Seeking by Remote Role')
plt.ylabel('Proportion')
plt.xlabel('Remote Position (at least 50% of the time)')
plt.xticks(rotation=45)
plt.legend(title='Treatment', loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

# %%
# Mental health benefits


# Observed consequences

# self employed


# 🧠 Look for correlations using heatmaps

# %% [markdown]
# #### Viz to Export
# - []

# %% [markdown]
# ### Keep in Mind for Write-Up
# - majority of US respondents are from CA, which may skew results and not be as representative of whole country's tech workers. Though one could argue that since CA (and other top respondent countries) is a tech hub in the US that it can be a quick snapshot, I would argue that there are other factors in these areas that can affect mental health greatly (ex. CA being known for Hollywood and high beauty standards and actors not "making it").
# - chose to drop respondents that input odd ages, locations (US states despite not in the USA), []. Posisbly no big difference, but worth it to keep this in mind.
# - due to high cost of living for some of the top locations, I wonder if high cost of living or financial constraints have more correlation that some of these features in the survey
# - I wonder if how many years in the field correlates to mental health treatment outcomes?
# - Based on survey Qs, it is difficult to know if someone **needed** mental health interventions/tx or if they had a dx, which is highly important info to know for the tx-seeking Q(s)
# - []

# %%
# import plotly
# print(plotly.__version__)
